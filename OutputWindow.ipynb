# %%
import pickle

# Load trained models from pickle files
model_names = ['Linear Regression', 'Decision Tree', 'Random Forest', 'Gradient Boost', 'XGBoost', 'Bagging Regressor', 'KNeighborsRegressor']
loaded_models = {}
for name in model_names:
    with open(f'{name}_model.pkl', 'rb') as f:
        loaded_models[name] = pickle.load(f)

# Load results from pickle file
with open('results.pkl', 'rb') as f:
    loaded_results_df = pickle.load(f)

# Now you can use loaded_models and loaded_results_df as needed

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd
import pickle
import numpy as np

# Load the trained Random Forest model
with open('Random Forest_model.pkl', 'rb') as f:
    trained_model = pickle.load(f)

# Load the OneHotEncoder object
with open('encoder.pkl', 'rb') as f:
    encoder = pickle.load(f)

# Load the DataFrame for encoding
df = pd.read_csv('yield_df.csv')

# Features used for training
numerical_features = ['average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp_x']
categorical_features = ['Area', 'Item']

# Function to predict values based on input
def predict_values():
    # Get the input values from the entry widgets
    area_name = area_entry.get()
    item_name = item_entry.get()
    avg_rainfall = float(avg_rainfall_entry.get())
    pesticides = float(pesticides_entry.get())
    avg_temp = float(avg_temp_entry.get())
    
    # Transform categorical variables using the encoder
    area_encoded = encoder.transform([[area_name]]).toarray()
    item_encoded = encoder.transform([[item_name]]).toarray()
    
    # Concatenate the encoded categorical features with numerical features
    input_features = np.concatenate((area_encoded, item_encoded, [[avg_rainfall, pesticides, avg_temp]]), axis=1)
    
    # Make the prediction using the trained model
    prediction = trained_model.predict(input_features)
    
    # Display the predicted value in the result label
    predicted_yield_label.config(text=f'Predicted Yield (hg/ha): {prediction[0]}')

# Create a tkinter window
window = tk.Tk()
window.title("Crop Yield Prediction")

# Create labels and entry widgets for input
area_label = ttk.Label(window, text="Enter Area Name:")
area_label.grid(row=0, column=0, padx=5, pady=5)
area_entry = ttk.Entry(window)
area_entry.grid(row=0, column=1, padx=5, pady=5)

item_label = ttk.Label(window, text="Enter Item Name:")
item_label.grid(row=1, column=0, padx=5, pady=5)
item_entry = ttk.Entry(window)
item_entry.grid(row=1, column=1, padx=5, pady=5)

avg_rainfall_label = ttk.Label(window, text="Enter Average Rainfall (mm per year):")
avg_rainfall_label.grid(row=2, column=0, padx=5, pady=5)
avg_rainfall_entry = ttk.Entry(window)
avg_rainfall_entry.grid(row=2, column=1, padx=5, pady=5)

pesticides_label = ttk.Label(window, text="Enter Pesticides (tonnes):")
pesticides_label.grid(row=3, column=0, padx=5, pady=5)
pesticides_entry = ttk.Entry(window)
pesticides_entry.grid(row=3, column=1, padx=5, pady=5)

avg_temp_label = ttk.Label(window, text="Enter Average Temperature (C):")
avg_temp_label.grid(row=4, column=0, padx=5, pady=5)
avg_temp_entry = ttk.Entry(window)
avg_temp_entry.grid(row=4, column=1, padx=5, pady=5)

# Create a button to trigger prediction
predict_button = ttk.Button(window, text="Predict", command=predict_values)
predict_button.grid(row=5, column=0, columnspan=2, padx=5, pady=5)

# Create a label to display predicted value
predicted_yield_label = ttk.Label(window, text="Predicted Yield: ")
predicted_yield_label.grid(row=6, column=0, columnspan=2, padx=5, pady=5, sticky='w')

# Run the tkinter event loop
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\SAURABH KALE\AppData\Local\Temp\ipykernel_18460\3988041658.py", line 32, in predict_values
#     area_encoded = encoder.transform([[area_name]]).toarray()
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\site-packages\sklearn\utils\_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\site-packages\sklearn\compose\_column_transformer.py", line 1007, in transform
#     self._check_n_features(X, reset=False)
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\site-packages\sklearn\base.py", line 443, in _check_n_features
#     raise ValueError(
# ...

# %%
# import tkinter as tk
# from tkinter import ttk
# import pandas as pd
# import pickle
# import numpy as np

# # Load the trained Random Forest model
# with open('Random Forest_model.pkl', 'rb') as f:
#     trained_model = pickle.load(f)

# # Load the OneHotEncoder object
# with open('encoder.pkl', 'rb') as f:
#     encoder = pickle.load(f)

# # Load the DataFrame for encoding
# df = pd.read_csv('yield_df.csv')

# # Features used for training
# numerical_features = ['average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp']
# categorical_features = ['Area', 'Item']

# # Function to predict values based on input
# def predict_values():
#     # Get the input values from the entry widgets
#     area_name = area_entry.get()
#     item_name = item_entry.get()
    
#     # Transform categorical variables using the encoder
#     area_encoded = encoder.transform([[area_name]]).toarray()
#     item_encoded = encoder.transform([[item_name]]).toarray()
    
#     # Find the corresponding row in the DataFrame
#     row = df[(df['Area'] == area_name) & (df['Item'] == item_name)]
    
#     if not row.empty:
#         # Extract the numerical feature values
#         numerical_input = row[numerical_features].values
        
#         # Concatenate the encoded categorical features with numerical features
#         input_features = np.concatenate((area_encoded, item_encoded, numerical_input), axis=1)
        
#         # Make the prediction using the trained model
#         prediction = trained_model.predict(input_features)
        
#         # Display the predicted values in the result labels
#         predicted_yield_label.config(text=f'Predicted Yield: {prediction[0]}')
#         # You can similarly display other predicted values
#     else:
#         predicted_yield_label.config(text="Area or Item not found")

# # Create a tkinter window
# window = tk.Tk()
# window.title("Crop Yield Prediction")

# # Create labels and entry widgets for input
# area_label = ttk.Label(window, text="Enter Area Name:")
# area_label.grid(row=0, column=0, padx=5, pady=5)
# area_entry = ttk.Entry(window)
# area_entry.grid(row=0, column=1, padx=5, pady=5)

# item_label = ttk.Label(window, text="Enter Item Name:")
# item_label.grid(row=1, column=0, padx=5, pady=5)
# item_entry = ttk.Entry(window)
# item_entry.grid(row=1, column=1, padx=5, pady=5)

# # Create a button to trigger prediction
# predict_button = ttk.Button(window, text="Predict", command=predict_values)
# predict_button.grid(row=2, column=0, columnspan=2, padx=5, pady=5)

# # Create labels to display predicted values
# predicted_yield_label = ttk.Label(window, text="Predicted Yield: ")
# predicted_yield_label.grid(row=3, column=0, columnspan=2, padx=5, pady=5, sticky='w')

# # You can create similar labels for other predicted values

# # Run the tkinter event loop
# window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\SAURABH KALE\AppData\Local\Temp\ipykernel_18460\2269706605.py", line 29, in predict_values
#     area_encoded = encoder.transform([[area_name]]).toarray()
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\site-packages\sklearn\utils\_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\site-packages\sklearn\compose\_column_transformer.py", line 1007, in transform
#     self._check_n_features(X, reset=False)
#   File "c:\Users\SAURABH KALE\anaconda3\envs\CY2\Lib\site-packages\sklearn\base.py", line 443, in _check_n_features
#     raise ValueError(
# ...
